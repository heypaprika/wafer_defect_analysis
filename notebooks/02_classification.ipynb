# %% [markdown]
# # 02 — Classification results
#
# Load `reports/classification/metrics.json`, plot per-class F1 and confusion matrix, compare focal vs CE.

# %%
import json, pathlib, pandas as pd
REPORT = pathlib.Path('..') / 'reports' / 'classification' / 'metrics.json'
metrics = json.loads(REPORT.read_text())
pd.DataFrame(metrics['per_class']).T
