# %% [markdown]
# # 04 — SECOM suspect factors
#
# Top-K KPIVs by |SHAP|, SHAP summary plot, partial dependence for the top 3 sensors.

# %%
import pandas as pd
suspects = pd.read_csv('../reports/factor/suspect_factors.csv')
suspects
