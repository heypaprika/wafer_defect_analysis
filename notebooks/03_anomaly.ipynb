# %% [markdown]
# # 03 — Novel-pattern detection
#
# AUROC, score histograms, per-defect-class mean reconstruction error, top-K reconstruction errors as candidate novel patterns.

# %%
import pandas as pd
scores = pd.read_csv('../reports/anomaly/scores.csv')
scores.groupby('label')['score'].agg(['mean','std','count']).sort_values('mean', ascending=False)
