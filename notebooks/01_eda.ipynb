# %% [markdown]
# # 01 — EDA: WM-811K + SECOM
#
# Class balance, wafer-map samples per class, lot distribution, SECOM missingness.

# %%
# %load_ext autoreload
# %autoreload 2

import sys, pathlib
ROOT = pathlib.Path.cwd().parent
sys.path.insert(0, str(ROOT))

from src.data.load_wm811k import load_wm811k
from src.data.load_secom import load_secom
